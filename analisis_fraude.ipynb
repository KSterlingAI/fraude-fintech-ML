# %% [markdown]
# <a href="https://colab.research.google.com/github/KSterlingAI/fraude-fintech-ML/blob/main/analisis_fraude.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Cargar el dataset correcto
data = pd.read_csv('fraude_fintech.csv')

# No necesitas crear 'fraude', ya existe
print(data.head())

# Selección de variables numéricas
num_cols = data.select_dtypes(include='number')
X = num_cols.drop(columns=['fraude'])
y = num_cols['fraude']

# División del conjunto
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Modelo
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Evaluación
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#    id_transaccion   monto tipo_transaccion       pais dispositivo  hora  \
# 0               1   56.31             pago  Argentina       movil     9
# 1               2  361.21             pago       Peru         web    22
# 2               3  158.01           compra     Mexico         POS     4
# 3               4  109.55             pago      Chile       movil    17
# 4               5   20.35           compra      Chile      cajero     8
#
#    dias_cuenta_creada  fraude
# 0                1163       0
# 1                1541       0
# 2                 578       0
# 3                1647       0
# 4                1208       0
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1480
#            1       0.00      0.00      0.00        20
#
#     accuracy                           0.99      1500
#    macro avg       0.49      0.50      0.50      1500
# weighted avg       0.97      0.99      0.98      1500
# ...
